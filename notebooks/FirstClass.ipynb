# %%
# Rango de años en pasos de cinco
year = [ii for ii in range(1950, 2006, 5)]

# %%
C = []
value = 0.0
while type(value) == float:
    value = float(input("Insert value > "))
# Out:
# [1950, 1955, 1960, 1965, 1970, 1975, 1980, 1985, 1990, 1995, 2000, 2005]

# %%
C = []
for ii in range(len(year)):
    C.append(float(input("Insert value > ")))
# Out:
# Insert value >  34.616
# Insert value >  40.208
# Insert value >  45.087
# Insert value >  54.017
# Insert value >  67.844
# Insert value >  71.999
# Insert value >  78.122
# Insert value >  76.491
# Insert value >  84.652
# Insert value >  91.173
# Insert value >  98.975
# Insert value >  100.506

# %%
print(year, C)
# Out:
# [1950, 1955, 1960, 1965, 1970, 1975, 1980, 1985, 1990, 1995, 2000, 2005] [34.616, 40.208, 45.087, 54.017, 67.844, 71.999, 78.122, 76.491, 84.652, 91.173, 98.975, 100.506]

# %%
m = (C[-1]-C[0])/(year[-1]-year[0])
b = (year[-1]*C[0]-year[0]*C[-1])/(year[-1]-year[0])
print(m,b)
# Out:
# 1.198 -2301.4840000000004

# %%
import matplotlib.pyplot as plt

# %%
ymod = [m*x+b for x in year]
plt.plot(year, C, "o")
plt.plot(year, ymod)

# %%
e = [(y-ym)/ym for y, ym in zip(C,ymod)]

# %%
plt.plot(year, e, "o")
plt.axhline(0)
